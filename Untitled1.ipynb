# %%
import requests
r = requests.get('http://api.urbansciences.in/avgNTs/1/imei/864502030077986/type/csv/start/20180224000000/end/20180228120000/ApiKey/sgLztY2xGJ')

# %%
import pandas as pd
df = pd.read_csv('http://api.urbansciences.in/avgNTs/1/imei/864502030077986/type/csv/start/20180224000000/end/20180228120000/ApiKey/sgLztY2xGJ')

# %%
df.index = pd.to_datetime(df.Date)

# %%
# %matplotlib inline

# %%
df.pm25conc_1hrs.plot(marker='o')

# %%
df.aqi.plot(kind='bar')

# %%
df.columns
# Out:
# Index(['IMEI', 'Date', 'pm1conc_1hrs', 'pm10conc_1hrs', 'pm25raw_1hrs',
#        'pm25conc_1hrs', 'aqi', ' latitude', ' longitude', ' humidity',
#        ' temperature', ' wind speed', ' wind direction', 'severity',
#        'health_impact'],
#       dtype='object')

# %%
df[' latitude'], df[' longitude']
# Out:
# (Date
#  2018-02-23 23:35:39.165    24.046
#  2018-02-24 00:30:31.566    24.046
#  2018-02-24 01:31:29.285    24.046
#  2018-02-24 02:30:09.386    24.046
#  2018-02-24 03:30:10.749    24.046
#  2018-02-24 04:30:33.666    24.046
#  2018-02-24 05:30:41.288    24.046
#  2018-02-24 06:30:47.144    24.046
#  2018-02-24 07:31:22.676    24.046
#  2018-02-24 08:30:45.386    24.046
#  2018-02-24 09:30:24.890    24.046
#  2018-02-24 10:30:30.952    24.046
#  2018-02-26 11:48:58.177    24.046
#  2018-02-26 12:30:05.670    24.046
#  2018-02-27 06:13:31.107    24.046
#  2018-02-27 06:30:56.836    24.046
#  2018-02-27 07:30:56.435    24.046
#  2018-02-27 08:30:27.792    24.046
#  2018-02-27 09:30:04.272    24.046
#  2018-02-27 10:30:42.184    24.046
#  2018-02-27 11:30:10.391    24.046
#  2018-02-27 12:30:33.590    24.046
#  2018-02-27 13:40:30.752    24.046
#  2018-02-27 14:30:51.473    24.046
#  2018-02-27 15:34:41.313    24.046
#  2018-02-27 16:34:39.075    24.046
# ...
