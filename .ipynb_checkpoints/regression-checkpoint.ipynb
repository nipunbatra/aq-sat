# %%
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
df = pd.read_csv("pm25-modis-10k.csv", index_col=0)
df.index = range(len(df))

# %%
regression_dictionary = {'KNN':KNeighborsRegressor(), 
                         'DT':DecisionTreeRegressor(),
                         'RF':RandomForestRegressor(),
                        'SVM':SVR(),
                        'Linear':LinearRegression()}

# %%
df.head()
# Out:
#    Cloud_Fraction    AOD                       Location        Date  \
# 0             0.0  0.918  US Diplomatic Post: New Delhi  2017-01-01
# 1             0.0  0.918                         Mandir  2017-01-01
# 2             0.0  0.389                   Punjabi Bagh  2017-01-02
# 3             0.0  0.389                         Mandir  2017-01-02
# 4             0.0  0.705  US Diplomatic Post: New Delhi  2017-01-05
#
#          PM25
# 0  156.612500
# 1  168.234043
# 2  174.054054
# 3  174.979167
# 4  166.120833

# %%
out = {}
for reg in regression_dictionary.keys():
    out[reg] = []
kf = KFold(n_splits=5)
X = df[['AOD','Cloud_Fraction']]
#X = df[['AOD']]
y = df.PM25

gt = []
for train_index, test_index in kf.split(df):
    X_train, X_test = X.ix[train_index], X.ix[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    gt.append(y_test)
    
    for reg_algo_name, reg in regression_dictionary.items():
        reg.fit(X_train, y_train)
        out[reg_algo_name].append(reg.predict(X_test))
# Out:
# /Users/nipun/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # This is added back by InteractiveShellApp.init_path()

# %%
import numpy as np
for reg in regression_dictionary.keys():
    out[reg] = np.array(out[reg]).flatten()

# %%
pd.DataFrame(out)
out["GT"] = np.array(gt).flatten()

# %%
np.array(gt).flatten().shape
# Out:
# (1170,)

# %%
pd.DataFrame(out)
# Out:
#               DT          GT         KNN      Linear          RF        SVM
# 0      79.721771  156.612500  108.457766   93.666524  130.117430  83.609172
# 1      79.721771  168.234043  108.457766   93.666524  130.117430  83.609172
# 2     114.275000  174.054054  110.837576   91.552514  113.095668  82.953578
# 3     114.275000  174.979167  110.837576   91.552514  113.095668  82.953578
# 4     178.601136  166.120833  103.903000   92.815325  129.804201  83.871656
# 5     178.601136  155.812500  103.903000   92.815325  129.804201  83.871656
# 6      64.916667  151.333333   78.299506   88.893145   73.093568  81.535474
# 7     123.510638  139.500000   79.996792   87.512180  101.335381  80.868530
# 8     124.921739  159.984783  115.911849   92.343745  125.342716  83.403399
# 9      59.489362  152.968750   65.448667   90.369760   65.659038  81.674298
# 10     59.489362  145.833333   57.841496   90.646832   62.502443  81.411085
# 11    160.289205  141.208333  113.207253   88.242031  134.315393  81.544892
# 12    160.289205  132.832609  113.207253   88.242031  134.315393  81.544892
# 13    112.110827  132.670833  107.091494   91.871303  119.333525  83.411859
# 14    112.110827  131.812500  107.091494   91.871303  119.333525  83.411859
# 15    112.110827  145.218750  107.091494   91.871303  119.333525  83.411859
# 16     73.513514  146.375000   77.665944   76.916793   70.604661  74.502893
# 17     88.229657  120.770833   83.878925   82.555074   52.921821  78.451504
# 18     90.451745  148.926667   94.968967   83.896935   81.967183  79.254235
# 19     90.451745  104.464286   92.303113   84.087324   86.205990  79.356916
# 20     90.451745  138.708333   92.303113   84.087324   86.205990  79.356916
# 21     69.744444  113.161290   77.520013   82.158300   83.547461  77.850397
# 22     65.492754  135.464444   96.381971   81.612423   87.329886  77.574221
# 23     65.492754  112.533333   96.381971   81.612423   87.329886  77.574221
# 24     65.492754  100.978947   96.381971   81.612423   87.329886  77.574221
# 25     89.666667  118.186047  107.422429   79.835384   91.379215  76.720251
# 26     65.492754  130.088235   96.381971   81.612423   87.329886  77.574221
# 27     84.500000  168.169565   73.484212   82.868424   95.640415  78.427295
# 28     84.500000  154.409091   73.484212   82.868424   95.640415  78.427295
# 29     84.500000  157.142857   73.484212   82.868424   95.640415  78.427295
# ...          ...         ...         ...         ...         ...        ...
# 1140   92.204688   75.584906  112.412844   88.226718   86.741058  87.269595
# 1141   92.204688  122.000000   94.286258   90.514191   78.789792  88.375787
# 1142   92.204688  144.641509  112.412844   88.226718   86.741058  87.269595
# 1143   98.916223  111.097551  109.251543   91.938795   92.990647  89.428034
# 1144   92.204688   91.056875   94.286258   90.514191   78.789792  88.375787
# 1145  159.984783   81.736111  132.049366   99.229197  107.918299  92.813398
# 1146  159.984783   89.593750  132.049366   99.229197  107.918299  92.813398
# 1147   61.317660  103.749375  140.750045   98.820318  123.729344  93.322152
# 1148  159.984783  162.958333  132.049366   99.229197  107.918299  92.813398
# 1149   69.100000  114.428750  116.216974   99.427552   69.574704  93.606655
# 1150  162.423271   72.537292  141.538366   98.767720  100.860882  92.224606
# 1151   98.448924  123.842456   92.557831   97.645673   91.732080  92.228053
# 1152   61.008986  126.974684  113.661602   96.267049   64.855723  92.047382
# 1153  159.984783   73.974219  132.049366   99.229197  107.918299  92.813398
# 1154   61.008986   73.624493  113.661602   96.267049   64.855723  92.047382
# 1155  162.423271   86.906250  141.538366   98.767720  100.860882  92.224606
# 1156   61.008986   48.716508  113.661602   96.267049   64.855723  92.047382
# 1157  159.984783  118.363636  132.049366   99.229197  107.918299  92.813398
# 1158   53.636364  115.845679   94.413072   93.869891   95.482313  90.345426
# 1159  163.364706   69.242222  119.212368  100.082274  126.717918  93.899863
# 1160   53.636364   76.612500   94.413072   93.869891   95.482313  90.345426
# 1161   53.636364   62.781094   94.413072   93.869891   95.482313  90.345426
# 1162   60.846957   91.145833   70.004682   90.665418   67.205325  88.704067
# 1163   60.846957   42.932794   70.004682   90.665418   67.205325  88.704067
# 1164   53.636364   83.479452   94.413072   93.869891   95.482313  90.345426
# 1165   60.846957  128.137500   70.004682   90.665418   67.205325  88.704067
# 1166  163.364706   95.481304  119.212368  100.082274  126.717918  93.899863
# 1167   53.636364   78.493333   94.413072   93.869891   95.482313  90.345426
# 1168   53.636364  103.830968  109.327238   93.657417  102.035626  90.233654
# 1169  137.020471  125.250000  120.024855   98.158089  117.584772  92.970613
#
# [1170 rows x 6 columns]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
mae = {}
r2 = {}
for reg_algo_name in regression_dictionary.keys():
    mae[reg_algo_name] = mean_absolute_error(out['GT'],out[reg_algo_name])
    r2[reg_algo_name] = r2_score(out['GT'],out[reg_algo_name])

# %%
pd.Series(mae)
# Out:
# DT        38.987742
# KNN       32.911805
# Linear    30.193754
# RF        33.042082
# SVM       30.919420
# dtype: float64

# %%
pd.Series(r2)
# Out:
# DT       -0.770719
# KNN      -0.259068
# Linear   -0.041267
# RF       -0.277091
# SVM      -0.092108
# dtype: float64

# %%
# %matplotlib inline

# %%
pd.DataFrame(out).plot(kind='scatter',x='DT',y='GT')

# %%
df.plot(kind='scatter',x='Cloud_Fraction',y='PM25')

# %%
o = pd.DataFrame(out)
o['Location'] = df.Location

# %%
e = {}
for reg in regression_dictionary.keys():
    e[reg] = (o[reg] - o['GT']).abs()

# %%
e['Location'] = o['Location']

# %%
import seaborn as sns

# %%
sns.heatmap(pd.DataFrame(e).groupby("Location").mean(), annot=True, cmap='Greens')

# %%
import matplotlib.pyplot as plt
df.groupby("Location").mean().PM25.sort_values().plot(kind='bar')
plt.ylabel("PM25")
