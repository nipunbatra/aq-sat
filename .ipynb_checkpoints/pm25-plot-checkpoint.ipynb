# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/nipun/Desktop/pm25.csv", index_col=[0])

# %%
df.index = pd.to_datetime(df.index)

# %%
# %matplotlib inline
df[df.location=='CRRI Mathura Road, Delhi - IMD'].value.plot()
