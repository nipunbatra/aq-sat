# %%
import requests
import pandas as pd

# %%
r = requests.get("https://api.openaq.org/v1/locations?city=Delhi&paramater=pm25")

# %%
all_cities = r.json()

# %%
pd.DataFrame(all_cities['results'])
# Out:
#      city                                      coordinates   count country  \
# 0   Delhi      {'latitude': 28.6508, 'longitude': 77.3152}  102326      IN
# 1   Delhi      {'latitude': 28.6508, 'longitude': 77.3152}    9327      IN
# 2   Delhi    {'latitude': 28.65274, 'longitude': 77.29779}     172      IN
# 3   Delhi     {'latitude': 28.69572, 'longitude': 77.1813}     753      IN
# 4   Delhi                                              NaN   11303      IN
# 5   Delhi   {'latitude': 28.470692, 'longitude': 77.10994}    3085      IN
# 6   Delhi                                              NaN   12367      IN
# 7   Delhi    {'latitude': 28.72565, 'longitude': 77.20116}    3754      IN
# 8   Delhi                                              NaN   10500      IN
# 9   Delhi    {'latitude': 28.5512, 'longitude': 77.273575}    5053      IN
# 10  Delhi      {'latitude': 28.6787, 'longitude': 77.2262}       4      IN
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
